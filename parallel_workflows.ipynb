# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv
import os
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel, Field
import operator

load_dotenv()
# Out:
# True

# %%
llm_endpoint = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    temperature=0.5,
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_API_TOKEN"))

llm = ChatHuggingFace(llm = llm_endpoint)

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description='Detailed feedbackfor the essay')
    score: int = Field(description='Score out of 10', ge=0, le=10)

# %%
llm = llm.with_structured_output(EvaluationSchema)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llm = llm.with_structured_output(EvaluationSchema)
#
# File c:\Users\dumpa\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_huggingface\chat_models\huggingface.py:1174, in ChatHuggingFace.with_structured_output(self, schema, method, include_raw, **kwargs)
#    1172     if is_pydantic_schema:
#    1173         msg = "Pydantic schema is not supported for function calling"
# -> 1174         raise NotImplementedError(msg)
#    1175     output_parser: JsonOutputKeyToolsParser | JsonOutputParser = (
#    1176         JsonOutputKeyToolsParser(key_name=tool_name, first_tool_only=True)
#    1177     )
#    1178 elif method == "json_schema":
#
# NotImplementedError: Pydantic schema is not supported for function calling
